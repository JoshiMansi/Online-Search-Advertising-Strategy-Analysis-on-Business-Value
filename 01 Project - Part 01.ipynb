# %% [markdown]
# ### <font color = 'Red'> Project 1: Data Wrangling and Regression Analysis
# **PART 1:** Data Collection and Preparation
#     1. Read the process the Fortune1000 data file
#     2. Add a column of Company URLs to the DataFrame
#     3. Extract/Scrape Search Advertising Related Data from A website

# %%
# import packages

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as beaut
import requests
import re
import warnings
from colorama import Fore, Style

# %%
# read txt file

with open("fortune1000.txt","r") as file:            # file to refer to object
    dataContent = file.readlines()                   # read the data into dataContent line by line
fileList = [line.strip() for line in dataContent]    # make a list with individual elements from newline
del fileList[-1]                                     # delete extra single extra last element
dataArr = np.array(fileList)                         # make array

# %%
# make dataframe
fortune_df = pd.DataFrame(dataArr.reshape(1000,11), columns = ['Rank','Name', 'Revenue($m)', '% Change in revenue', 
                                                        'Profits($m)', '% Change in Profits', 'Assets($m)',
                                                        'Market Value($m)', 'Change in Rank (1000)', 'Employees',
                                                        'Change in Rank (500 Only)'])

# %%
# drop extra columns
fortune_df = fortune_df.drop(['% Change in revenue', '% Change in Profits',
                              'Change in Rank (1000)','Change in Rank (500 Only)'], axis=1)

# %%
# df specifications

#fortune_df.shape               # column row count
fortune_df.head()              # data peak
#fortune_df.describe()          # statistic details
#fortune_df.info()              # column list
#fortune_df.isna().any()        # check NA
# Out:
#   Rank         Name Revenue($m) Profits($m) Assets($m) Market Value($m)  \
# 0    1      Walmart    $523,964     $14,881   $236,495       $321,803.3
# 1    2   Amazon.com    $280,522     $11,588   $225,248       $970,680.1
# 2    3  Exxon Mobil    $264,938     $14,340   $362,597       $160,696.3
# 3    4        Apple    $260,174     $55,256   $338,516     $1,112,640.8
# 4    5   CVS Health    $256,776      $6,634   $222,449        $77,375.8
#
#    Employees
# 0  2,200,000
# 1    798,000
# 2     74,900
# 3    137,000
# 4    290,000

# %%
# clean data to remove '$' and ','
fortune_df = fortune_df.replace('\$|,', '', regex=True)
fortune_df = fortune_df.replace('-', np.nan, regex=True)

# %% [markdown]
# ### <font style = 'italic'> eof

# %%
# export processed sample set
fortune_df.to_csv('fortune_df.csv')

# %%
# read processed sample set
fortune_df = pd.read_csv("fortune_df.csv")
fortune_df = fortune_df.drop(fortune_df.columns[[0]],axis=1)

# %%
# df specifications

#fortune_df.shape               # column row count
#fortune_df.head()              # data peak
#fortune_df.describe()          # statistic details
fortune_df.info()               # column list
#fortune_df.isna().any()        # check NA
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              1000 non-null   int64
#  1   Name              969 non-null    object
#  2   Revenue($m)       1000 non-null   float64
#  3   Profits($m)       854 non-null    float64
#  4   Assets($m)        1000 non-null   float64
#  5   Market Value($m)  950 non-null    float64
#  6   Employees         1000 non-null   int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 54.8+ KB

# %% [markdown]
# **Part 2:**

# %%
# read csv file
fortuneURLs_df = pd.read_csv("fortuneURL_df.csv")

# drop extra columns
fortuneURLs_df = fortuneURLs_df.drop(['Unnamed: 0'], axis=1)
# fortuneURLs_df = fortuneURLs_df.drop(['Rank', 'Name','Revenue($m)','Profits($m)','Assets($m)','Market Value($m)','Employees'], axis=1)

# drop rows with null URLs
# fortuneURLs_df = fortuneURLs_df.dropna(axis=0, subset=['URLs'])

# reset index
fortuneURLs_df = fortuneURLs_df.reset_index(drop=True)

# %%
# df specifications

#fortuneURLs_df.shape               # column row count
#fortuneURLs_df.head()              # data peak
#fortuneURLs_df.describe()          # statistic details
fortuneURLs_df.info()              # column list
#fortuneURLs_df.isna().any()        # check NA
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank              423 non-null    int64
#  1   Name              423 non-null    object
#  2   Revenue($m)       423 non-null    float64
#  3   Profits($m)       390 non-null    float64
#  4   Assets($m)        423 non-null    float64
#  5   Market Value($m)  395 non-null    float64
#  6   Employees         423 non-null    int64
#  7   URLs              423 non-null    object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 26.6+ KB

# %%
# add webiste outlook site url for scraping

fortuneURLs_df['wout'] = fortuneURLs_df['URLs'] + '.websiteoutlook.com'

# %%
# add empty columns to collect website attributes

fortuneURLs_df['alexaRank'] = ""
fortuneURLs_df['backlinks'] = ""
fortuneURLs_df['pageAuthority'] = ""
fortuneURLs_df['domainAuthority'] = ""
fortuneURLs_df['mozRank'] = ""
fortuneURLs_df['pageviews'] = ""
fortuneURLs_df['worth'] = ""

fortuneURLs_df['pageSize'] = ""
fortuneURLs_df['codeToTextRatio'] = ""

fortuneURLs_df['semrushRank'] = ""
fortuneURLs_df['keywords'] = ""
fortuneURLs_df['organicTraffic'] = ""
fortuneURLs_df['cost'] = ""
fortuneURLs_df['adwordsKeywords'] = ""
fortuneURLs_df['adwordsTraffic'] = ""
fortuneURLs_df['adwordsBudget'] = ""

fortuneURLs_df['is_run'] = 0

# %% [markdown]
# **Single website Run:** Print Check for all attributes

# %%
# website outlook URL for test run
print(fortuneURLs_df['wout'][0])
# Out:
# http://www.walmart.com.websiteoutlook.com

# %%
# beaut object creation
response = requests.get(fortuneURLs_df['wout'][1])
soup = beaut(response.content, "html.parser")

# %%
print('alexaRank: ' + soup.find('span',{"class":"label label-primary"}).get_text().strip())
print('backlinks: ' + soup.find('span',{"class":"label label-default"}).get_text().strip())
print('pageAuthority: ' + soup.find('span',{"class":"label label-info"}).get_text().strip())
print('domainAuthority: ' + soup.find('span',{"class":"label label-info"}).get_text().strip())
print('mozRank: ' + soup.find('span',{"class":"label label-info"}).get_text().strip())
print('pageviews: ' + soup.find('span',{"class":"label label-warning"}).get_text().strip())
print('worth: ' + soup.find('span',{"class":"label label-danger"}).get_text().strip())

print('pageSize: ' + soup.find("dt",text="Page Size").findNext("dd").string.strip())
print('codeToTextRatio: ' + soup.find("dt",text="Code to Text Ratio").findNext("dd").text.split('(')[0].strip())

print('semrushRank:' + soup.find("td",text="Semrush Rank").findNext("td").text.strip())
print('keywords:' + soup.find("td",text="Keywords").findNext("td").text.strip())
print('organicTraffic:' + soup.find("td",text="Organic Traffic").findNext("td").text.strip())
print('cost:' + soup.find("td",text="Cost (in USD)").findNext("td").text.strip())
print('adwordsKeywords:' + soup.find("td",text="Adwords Keyword").findNext("td").text.strip())
print('adwordsTraffic:' + soup.find("td",text="Adwords Traffic").findNext("td").text.strip())
print('adwordsBudget:' + soup.find("td",text="Adwords budget (in USD)").findNext("td").text.strip())
# Out:
# alexaRank: 14
# backlinks: 0
# pageAuthority: 0/100
# domainAuthority: 0/100
# mozRank: 0/100
# pageviews: 78.57M/ Day
# worth: 172.07M
# pageSize: 64Kb
# codeToTextRatio: 0.27%
# semrushRank:3
# keywords:91384723
# organicTraffic:950416767
# cost:724598977$
# adwordsKeywords:79995
# adwordsTraffic:2943519
# adwordsBudget:9398034$

# %% [markdown]
# **All URL Runs:**
#
# _With time delay inserted between each run to avoid timeout exceptions_

# %%
warnings.filterwarnings('ignore')
runner = 0

for i in range(len(fortuneURLs_df['wout'])):

    # check URL exists
    if not fortuneURLs_df['wout'][i]:
        continue
        
    # print url for tracking
    print(str(i) + ' ' + fortuneURLs_df['wout'][i], end = '')
    
    # check port errors
    if fortuneURLs_df['is_run'][i] == -1:
        print(f'{Fore.RED}\033[1m: Not Run: Port Errors{Style.RESET_ALL}')
        continue
    
    # check is run flag
    if fortuneURLs_df['is_run'][i] >= 1:
        print(f'{Fore.GREEN}\033[1m: Not Run: Exists{Style.RESET_ALL}')
        continue
                
    # beaut object creation
    try:
        response = requests.get(fortuneURLs_df['wout'][i])
        soup = beaut(response.content, "html.parser")
        response.close() 
        runner += 1
    except:
        fortuneURLs_df['is_run'][i] = -1
        print(f'{Fore.RED}\033[1m: New Port Exception{Style.RESET_ALL}')
        continue

    # append data to columns if not null
    try:
        fortuneURLs_df['alexaRank'][i] = soup.find('span',{"class":"label label-primary"}).get_text().strip()
        fortuneURLs_df['backlinks'][i] = soup.find('span',{"class":"label label-default"}).get_text().strip()
        fortuneURLs_df['pageAuthority'][i] = soup.find('span',{"class":"label label-info"}).get_text().strip()
        fortuneURLs_df['domainAuthority'][i] = soup.find('span',{"class":"label label-info"}).get_text().strip()
        fortuneURLs_df['mozRank'][i] = soup.find('span',{"class":"label label-info"}).get_text().strip()
        fortuneURLs_df['pageviews'][i] = soup.find('span',{"class":"label label-warning"}).get_text().strip()
        fortuneURLs_df['worth'][i] = soup.find('span',{"class":"label label-danger"}).get_text().strip()
        fortuneURLs_df['is_run'][i] = 1
        print(f'{Fore.GREEN}\033[1m: 1...{Style.RESET_ALL}', end = '')
    except:
        print(f'{Fore.RED}\033[1m: New Scraping Exception 1st Block{Style.RESET_ALL}')
        continue

    try:
        fortuneURLs_df['pageSize'][i] = soup.find("dt",text="Page Size").findNext("dd").string.strip()
        fortuneURLs_df['codeToTextRatio'][i] = soup.find("dt",text="Code to Text Ratio").findNext("dd").text.split('(')[0].strip()
        fortuneURLs_df['is_run'][i] = 2
        print(f'{Fore.GREEN}\033[1m: 2...{Style.RESET_ALL}', end = '')
    except:
        print(f'{Fore.RED}\033[1m: New Scraping Exception 2nd Block{Style.RESET_ALL}')
        continue

    try:
        fortuneURLs_df['semrushRank'][i] = soup.find("td",text="Semrush Rank").findNext("td").text.strip()
        fortuneURLs_df['keywords'][i] = soup.find("td",text="Keywords").findNext("td").text.strip()
        fortuneURLs_df['organicTraffic'][i] = soup.find("td",text="Organic Traffic").findNext("td").text.strip()
        fortuneURLs_df['cost'][i] = soup.find("td",text="Cost (in USD)").findNext("td").text.strip()
        fortuneURLs_df['adwordsKeywords'][i] = soup.find("td",text="Adwords Keyword").findNext("td").text.strip()
        fortuneURLs_df['adwordsTraffic'][i] = soup.find("td",text="Adwords Traffic").findNext("td").text.strip()
        fortuneURLs_df['adwordsBudget'][i] = soup.find("td",text="Adwords budget (in USD)").findNext("td").text.strip()
        fortuneURLs_df['is_run'][i] = 3
        print(f'{Fore.GREEN}\033[1m: 3...{Style.RESET_ALL}', end = '')
        print(f'{Fore.GREEN}\033[1m: Just Completed{Style.RESET_ALL}')
    except:
        print(f'{Fore.RED}\033[1m: New Scraping Exception 3rd Block{Style.RESET_ALL}')
        continue

    # time delay for ease of search
    if runner < 50:
        sleep(3 + runner/10)
    elif runner < 100:
        sleep(3 + 2 * runner/10)
    elif runner < 200:
        sleep(8)
    elif runner < 300:
        sleep(8 + runner/10)
    else:
        sleep(8 + 2 * runner/10)
# Out:
# 0 http://www.walmart.com.websiteoutlook.com: Not Run: Exists
# 1 http://www.amazon.com.websiteoutlook.com: Not Run: Exists
# 2 http://www.apple.com.websiteoutlook.com: Not Run: Exists
# 3 http://www.cvshealth.com.websiteoutlook.com: Not Run: Port Errors
# 4 http://www.unitedhealthgroup.com.websiteoutlook.com: Not Run: Exists
# 5 http://www.mckesson.com.websiteoutlook.com: Not Run: Exists
# 6 http://www.att.com.websiteoutlook.com: Not Run: Exists
# 7 http://www.amerisourcebergen.com.websiteoutlook.com: Not Run: Exists
# 8 http://www.google.com.websiteoutlook.com: Not Run: Exists
# 9 http://www.cigna.com.websiteoutlook.com: Not Run: Exists
# 10 http://www.cardinal.com.websiteoutlook.com: Not Run: Exists
# 11 http://www.microsoft.com.websiteoutlook.com: Not Run: Exists
# 12 http://www.marathonpetroleum.com.websiteoutlook.com: Not Run: Exists
# 13 http://www.homedepot.com.websiteoutlook.com: Not Run: Exists
# 14 http://www.comcastcorporation.com.websiteoutlook.com: New Scraping Exception 1st Block
# 15 http://www.antheminc.com.websiteoutlook.com: Not Run: Exists
# 16 http://www.wellsfargo.com.websiteoutlook.com: Not Run: Exists
# 17 http://www.jnj.com.websiteoutlook.com: Not Run: Exists
# 18 http://www.freddiemac.com.websiteoutlook.com: Not Run: Exists
# 19 http://www.centene.com.websiteoutlook.com: Not Run: Exists
# 20 http://www.lowes.com.websiteoutlook.com: Not Run: Exists
# 21 http://www.intel.com.websiteoutlook.com: Not Run: Exists
# 22 http://www.facebook.com.websiteoutlook.com: Not Run: Exists
# 23 http://www.fedex.com.websiteoutlook.com: Not Run: Exists
# 24 http://www.disney.com.websiteoutlook.com: Not Run: Exists
# 25 http://www.humana.com.websiteoutlook.com: Not Run: Exists
# 26 http://www.prudential.com.websiteoutlook.com: Not Run: Exists
# 27 http://www.sysco.com.websiteoutlook.com: Not Run: Exists
# 28 http://www.lockheedmartin.com.websiteoutlook.com: Not Run: Exists
# 29 http://www.gs.com.websiteoutlook.com: Not Run: Exists
# 30 http://www.morganstanley.com.websiteoutlook.com: Not Run: Exists
# 31 http://www.americanexpress.com.websiteoutlook.com: Not Run: Exists
# 32 http://www.delta.com.websiteoutlook.com: Not Run: Exists
# 33 http://www.merck.com.websiteoutlook.com: Not Run: Exists
# 34 http://www.aa.com.websiteoutlook.com: Not Run: Exists
# 35 http://www.charter.com.websiteoutlook.com: Not Run: Exists
# 36 http://www.allstate.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 37 http://www.newyorklife.com.websiteoutlook.com: Not Run: Exists
# 38 http://www.nationwide.com.websiteoutlook.com: Not Run: Exists
# 39 http://www.libertymutual.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 40 http://www.tysonfoods.com.websiteoutlook.com: Not Run: Exists
# 41 http://www.tjx.com.websiteoutlook.com: Not Run: Exists
# 42 http://www.generaldynamics.com.websiteoutlook.com: Not Run: Exists
# 43 http://www.johndeere.com.websiteoutlook.com: Not Run: Port Errors
# 44 http://www.nike.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 45 http://www.progressive.com.websiteoutlook.com: Not Run: Exists
# 46 http://www.publix.com.websiteoutlook.com: Not Run: Exists
# 47 http://www.massmutual.com.websiteoutlook.com: Not Run: Exists
# 48 http://www.techdata.com.websiteoutlook.com: Not Run: Exists
# 49 http://www.usaa.com.websiteoutlook.com: Not Run: Exists
# 50 http://www.exeloncorp.com.websiteoutlook.com: Not Run: Exists
# 51 http://www.northropgrumman.com.websiteoutlook.com: Not Run: Port Errors
# 52 http://www.capitalone.com.websiteoutlook.com: Not Run: Exists
# 53 http://www.abbvie.com.websiteoutlook.com: Not Run: Exists
# 54 http://www.northwesternmutual.com.websiteoutlook.com: Not Run: Exists
# 55 http://www.abbott.com.websiteoutlook.com: Not Run: Exists
# 56 http://www.raytheon.com.websiteoutlook.com: Not Run: Exists
# 57 http://www.arrow.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 58 http://www.dollargeneral.com.websiteoutlook.com: Not Run: Exists
# 59 http://www.usbank.com.websiteoutlook.com: Not Run: Exists
# 60 http://www.starbucks.com.websiteoutlook.com: Not Run: Exists
# 61 http://www.paccar.com.websiteoutlook.com: Not Run: Exists
# 62 http://www.thermofisher.com.websiteoutlook.com: Not Run: Port Errors
# 63 http://www.pbfenergy.com.websiteoutlook.com: Not Run: Exists
# 64 http://www.nglenergypartners.com.websiteoutlook.com: Not Run: Exists
# 65 http://www.cbre.com.websiteoutlook.com: Not Run: Exists
# 66 http://www.synnex.com.websiteoutlook.com: Not Run: Exists
# 67 http://www.dollartree.com.websiteoutlook.com: Not Run: Exists
# 68 http://www.cummins.com.websiteoutlook.com: Not Run: Exists
# 69 http://www.unfi.com.websiteoutlook.com: Not Run: Exists
# 70 http://www.micron.com.websiteoutlook.com: Not Run: Exists
# 71 http://www.amgen.com.websiteoutlook.com: Not Run: Exists
# 72 http://www.penskeautomotive.com.websiteoutlook.com: Not Run: Exists
# 73 http://www.visa.com.websiteoutlook.com: Not Run: Exists
# 74 http://www.broadcom.com.websiteoutlook.com: Not Run: Port Errors
# 75 http://www.nucor.com.websiteoutlook.com: Not Run: Exists
# 76 http://www.southwest.com.websiteoutlook.com: Not Run: Exists
# 77 http://www.centurylink.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 78 http://www.lilly.com.websiteoutlook.com: Not Run: Exists
# 79 http://www.lennar.com.websiteoutlook.com: Not Run: Exists
# 80 http://www.pnc.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 81 http://www.southerncompany.com.websiteoutlook.com: Not Run: Exists
# 82 http://www.autonation.com.websiteoutlook.com: Not Run: Port Errors
# 83 http://www.marriott.com.websiteoutlook.com: Not Run: Exists
# 84 http://www.thehartford.com.websiteoutlook.com: Not Run: Exists
# 85 http://www.aecom.com.websiteoutlook.com: Not Run: Exists
# 86 http://www.netflix.com.websiteoutlook.com: Not Run: Exists
# 87 http://www.lear.com.websiteoutlook.com: Not Run: Exists
# 88 http://www.altria.com.websiteoutlook.com: Not Run: Exists
# 89 http://www.genpt.com.websiteoutlook.com: Not Run: Exists
# 90 http://www.nexteraenergy.com.websiteoutlook.com: Not Run: Exists
# 91 http://www.carmax.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 92 http://www.westrock.com.websiteoutlook.com: Not Run: Exists
# 93 http://www.cdw.com.websiteoutlook.com: Not Run: Exists
# 94 http://www.jll.com.websiteoutlook.com: Not Run: Exists
# 95 http://www.drhorton.com.websiteoutlook.com: Not Run: Exists
# 96 http://www.tenneco.com.websiteoutlook.com: Not Run: Exists
# 97 http://www.bd.com.websiteoutlook.com: Not Run: Exists
# 98 http://www.lfg.com.websiteoutlook.com: Not Run: Exists
# 99 http://www.salesforce.com.websiteoutlook.com: Not Run: Exists
# 100 http://www.mastercard.com.websiteoutlook.com: Not Run: Exists
# 101 http://www.molinahealthcare.com.websiteoutlook.com: Not Run: Exists
# 102 http://www.cognizant.com.websiteoutlook.com: Not Run: Exists
# 103 http://www.mmc.com.websiteoutlook.com: Not Run: Exists
# 104 http://www.xpo.com.websiteoutlook.com: Not Run: Exists
# 105 http://www.westerndigital.com.websiteoutlook.com: Not Run: Exists
# 106 http://www.aramark.com.websiteoutlook.com: Not Run: Exists
# 107 http://www.principal.com.websiteoutlook.com: Not Run: Exists
# 108 http://www.rossstores.com.websiteoutlook.com: Not Run: Exists
# 109 http://www.nordstrom.com.websiteoutlook.com: Not Run: Port Errors
# 110 http://www.jacobs.com.websiteoutlook.com: Not Run: Exists
# 111 http://www.wm.com.websiteoutlook.com: Not Run: Exists
# 112 http://www.chrobinson.com.websiteoutlook.com: Not Run: Exists
# 113 http://www.ecolab.com.websiteoutlook.com: Not Run: Exists
# 114 http://www.stryker.com.websiteoutlook.com: Not Run: Port Errors
# 115 http://www.appliedmaterials.com.websiteoutlook.com: Not Run: Exists
# 116 http://www.blackrock.com.websiteoutlook.com: Not Run: Port Errors
# 117 http://www.stanleyblackanddecker.com.websiteoutlook.com: Not Run: Exists
# 118 http://www.ti.com.websiteoutlook.com: Not Run: Port Errors
# 119 http://www.biogen.com.websiteoutlook.com: Not Run: Exists
# 120 http://www.rgare.com.websiteoutlook.com: Not Run: Exists
# 121 http://www.adp.com.websiteoutlook.com: Not Run: Exists
# 122 http://www.discoverfinancial.com.websiteoutlook.com: Not Run: Exists
# 123 http://www.vfc.com.websiteoutlook.com: Not Run: Exists
# 124 http://www.guardianlife.com.websiteoutlook.com: Not Run: Exists
# 125 http://www.ameriprise.com.websiteoutlook.com: Not Run: Exists
# 126 http://www.lb.com.websiteoutlook.com: Not Run: Port Errors
# 127 http://www.mgmresorts.com.websiteoutlook.com: Not Run: Exists
# 128 http://www.lithia.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 129 http://www.amfam.com.websiteoutlook.com: Not Run: Exists
# 130 http://www.farmers.com.websiteoutlook.com: Not Run: Exists
# 131 http://www.lkqcorp.com.websiteoutlook.com: Not Run: Port Errors
# 132 http://www.sempra.com.websiteoutlook.com: Not Run: Exists
# 133 http://www.centerpointenergy.com.websiteoutlook.com: Not Run: Exists
# 134 http://www.quantaservices.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 135 http://www.group1auto.com.websiteoutlook.com: Not Run: Exists
# 136 http://www.unum.com.websiteoutlook.com: Not Run: Exists
# 137 http://www.autozone.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 138 http://www.pacificlife.com.websiteoutlook.com: Not Run: Exists
# 139 http://www.aboutschwab.com.websiteoutlook.com: Not Run: Exists
# 140 http://www.crowncork.com.websiteoutlook.com: Not Run: Port Errors
# 141 http://www.ally.com.websiteoutlook.com: Not Run: Exists
# 142 http://www.labcorp.com.websiteoutlook.com: Not Run: Exists
# 143 http://www.livenation.com.websiteoutlook.com: Not Run: Exists
# 144 http://www.corning.com.websiteoutlook.com: Not Run: Port Errors
# 145 http://www.grainger.com.websiteoutlook.com: Not Run: Exists
# 146 http://www.ball.com.websiteoutlook.com: Not Run: Exists
# 147 http://www.uhsinc.com.websiteoutlook.com: Not Run: Exists
# 148 http://www.leidos.com.websiteoutlook.com: Not Run: Exists
# 149 http://www.nvidia.com.websiteoutlook.com: Not Run: Exists
# 150 http://www.bostonscientific.com.websiteoutlook.com: Not Run: Exists
# 151 http://www.steeldynamics.com.websiteoutlook.com: Not Run: Exists
# 152 http://www.mutualofomaha.com.websiteoutlook.com: Not Run: Port Errors
# 153 http://www.sonicautomotive.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 154 http://www.fisglobal.com.websiteoutlook.com: Not Run: Exists
# 155 http://www.republicservices.com.websiteoutlook.com: Not Run: Exists
# 156 http://www.libertymedia.com.websiteoutlook.com: Not Run: Exists
# 157 http://www.interpublic.com.websiteoutlook.com: Not Run: Port Errors
# 158 http://www.pultegroupinc.com.websiteoutlook.com: Not Run: Exists
# 159 http://www.fiserv.com.websiteoutlook.com: Not Run: Exists
# 160 http://www.borgwarner.com.websiteoutlook.com: Not Run: Exists
# 161 http://www.oreillyauto.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 162 http://www.newscorp.com.websiteoutlook.com: Not Run: Exists
# 163 http://www.calpine.com.websiteoutlook.com: Not Run: Exists
# 164 http://www.mohawkind.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 165 http://www.pvh.com.websiteoutlook.com: Not Run: Port Errors
# 166 http://www.campbellsoupcompany.com.websiteoutlook.com: Not Run: Exists
# 167 http://www.53.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 168 http://www.lamresearch.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 169 http://www.markelcorp.com.websiteoutlook.com: Not Run: Exists
# 170 http://www.unitedrentals.com.websiteoutlook.com: Not Run: Exists
# 171 http://www.pxd.com.websiteoutlook.com: Not Run: Exists
# 172 http://www.delekus.com.websiteoutlook.com: Not Run: Port Errors
# 173 http://www.emcorgroup.com.websiteoutlook.com: Not Run: Exists
# 174 http://www.jbhunt.com.websiteoutlook.com: Not Run: Exists
# 175 http://www.kkr.com.websiteoutlook.com: Not Run: Exists
# 176 http://www.alleghany.com.websiteoutlook.com: Not Run: Exists
# 177 http://www.ryder.com.websiteoutlook.com: Not Run: Exists
# 178 http://www.huntingtoningalls.com.websiteoutlook.com: Not Run: Port Errors
# 179 http://www.anixter.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 180 http://www.alaskaair.com.websiteoutlook.com: Not Run: Port Errors
# 181 http://www.dickssportinggoods.com.websiteoutlook.com: Not Run: Exists
# 182 http://www.coty.com.websiteoutlook.com: Not Run: Port Errors
# 183 http://www.erieinsurance.com.websiteoutlook.com: Not Run: Exists
# 184 http://www.oshkoshcorporation.com.websiteoutlook.com: Not Run: Port Errors
# 185 http://www.caseys.com.websiteoutlook.com: Not Run: Port Errors
# 186 http://www.tractorsupply.com.websiteoutlook.com: Not Run: Exists
# 187 http://www.commscope.com.websiteoutlook.com: Not Run: Port Errors
# 188 http://www.afginc.com.websiteoutlook.com: Not Run: Exists
# 189 http://www.sanmina.com.websiteoutlook.com: Not Run: Port Errors
# 190 http://www.amphenol.com.websiteoutlook.com: Not Run: Exists
# 191 http://www.andersonsinc.com.websiteoutlook.com: Not Run: Exists
# 192 http://www.westlake.com.websiteoutlook.com: Not Run: Exists
# 193 http://www.cbrands.com.websiteoutlook.com: Not Run: Port Errors
# 194 http://www.frontier.com.websiteoutlook.com: Not Run: Exists
# 195 http://www.jetblue.com.websiteoutlook.com: Not Run: Exists
# 196 http://www.raymondjames.com.websiteoutlook.com: Not Run: Exists
# 197 www.zimmerbiomet.com.websiteoutlook.com: Not Run: Port Errors
# 198 http://www.cinfin.com.websiteoutlook.com: Not Run: Exists
# 199 http://www.westernsouthern.com.websiteoutlook.com: Not Run: Exists
# 200 http://www.thorindustries.com.websiteoutlook.com: New Scraping Exception 1st Block
# 201 http://www.regeneron.com.websiteoutlook.com: Not Run: Exists
# 202 http://www.jmsmucker.com.websiteoutlook.com: Not Run: Exists
# 203 http://www.insight.com.websiteoutlook.com: Not Run: Port Errors
# 204 http://www.key.com.websiteoutlook.com: Not Run: Exists
# 205 http://www.americantower.com.websiteoutlook.com: Not Run: Exists
# 206 http://www.graybar.com.websiteoutlook.com: Not Run: Exists
# 207 www.wecenergygroup.com.websiteoutlook.com: Not Run: Port Errors
# 208 http://www.nvrinc.com.websiteoutlook.com: Not Run: Exists
# 209 http://www.burlingtonstores.com.websiteoutlook.com: Not Run: Exists
# 210 http://www.tollbrothers.com.websiteoutlook.com: Not Run: Exists
# 211 http://www.oldrepublic.com.websiteoutlook.com: Not Run: Exists
# 212 http://www.asburyauto.com.websiteoutlook.com: Not Run: Exists
# 213 http://www.ajg.com.websiteoutlook.com: Not Run: Exists
# 214 http://www.mastec.com.websiteoutlook.com: Not Run: Port Errors
# 215 http://www.owenscorning.com.websiteoutlook.com: Not Run: Port Errors
# 216 http://www.magellanhealth.com.websiteoutlook.com: Not Run: Exists
# 217 http://www.becn.com.websiteoutlook.com: New Scraping Exception 1st Block
# 218 http://www.hanes.com.websiteoutlook.com: Not Run: Exists
# 219 http://www.packagingcorp.com.websiteoutlook.com: New Scraping Exception 1st Block
# 220 http://www.northerntrust.com.websiteoutlook.com: Not Run: Exists
# 221 http://www.cintas.com.websiteoutlook.com: Not Run: Exists
# 222 http://www.intuit.com.websiteoutlook.com: Not Run: Exists
# 223 http://www.regions.com.websiteoutlook.com: Not Run: Exists
# 224 http://www.fmglobal.com.websiteoutlook.com: Not Run: Exists
# 225 http://www.amd.com.websiteoutlook.com: Not Run: Exists
# 226 http://www.boozallen.com.websiteoutlook.com: Not Run: Exists
# 227 http://www.wynnresorts.com.websiteoutlook.com: Not Run: Exists
# 228 http://www.securian.com.websiteoutlook.com: Not Run: Exists
# 229 http://www.alliancedata.com.websiteoutlook.com: Not Run: Exists
# 230 http://www.theice.com.websiteoutlook.com: Not Run: Exists
# 231 http://www.aam.com.websiteoutlook.com: Not Run: Exists
# 232 http://www.abm.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 233 http://www.activisionblizzard.com.websiteoutlook.com: Not Run: Port Errors
# 234 http://www.saic.com.websiteoutlook.com: Not Run: Port Errors
# 235 http://www.zoetis.com.websiteoutlook.com: Not Run: Exists
# 236 http://www.ascenaretail.com.websiteoutlook.com: Not Run: Exists
# 237 http://www.firstam.com.websiteoutlook.com: Not Run: Exists
# 238 http://www.graphicpkg.com.websiteoutlook.com: Not Run: Exists
# 239 http://www.olin.com.websiteoutlook.com: Not Run: Port Errors
# 240 http://www.roberthalf.com.websiteoutlook.com: Not Run: Exists
# 241 http://www.amtd.com.websiteoutlook.com: Not Run: Port Errors
# 242 http://www.analog.com.websiteoutlook.com: Not Run: Exists
# 243 http://www.rushenterprises.com.websiteoutlook.com: Not Run: Exists
# 244 http://www.fbhs.com.websiteoutlook.com: Not Run: Exists
# 245 http://www.levistrauss.com.websiteoutlook.com: Not Run: Port Errors
# 246 http://www.crowncastle.com.websiteoutlook.com: Not Run: Exists
# 247 http://www.simon.com.websiteoutlook.com: Not Run: Exists
# 248 http://www.cerner.com.websiteoutlook.com: Not Run: Exists
# 249 http://www.postholdings.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 250 http://www.huntington.com.websiteoutlook.com: Not Run: Exists
# 251 http://www.sprouts.com.websiteoutlook.com: Not Run: Exists
# 252 http://www.lpl.com.websiteoutlook.com: Not Run: Exists
# 253 http://www.troweprice.com.websiteoutlook.com: Not Run: Exists
# 254 http://www.chipotle.com.websiteoutlook.com: Not Run: Port Errors
# 255 http://www.pattersoncompanies.com.websiteoutlook.com: Not Run: Exists
# 256 http://www.rpminc.com.websiteoutlook.com: Not Run: Exists
# 257 http://www.equinix.com.websiteoutlook.com: Not Run: Exists
# 258 http://www.onsemi.com.websiteoutlook.com: Not Run: Exists
# 259 http://www.transdigm.com.websiteoutlook.com: Not Run: Port Errors
# 260 http://www.selectmedicalholdings.com.websiteoutlook.com: New Scraping Exception 1st Block
# 261 http://www.parpacific.com/.websiteoutlook.com: New Scraping Exception 1st Block
# 262 http://www.ropertech.com.websiteoutlook.com: New Scraping Exception 1st Block
# 263 http://www.mccormickcorporation.com.websiteoutlook.com: Not Run: Exists
# 264 http://www.mdu.com.websiteoutlook.com: Not Run: Port Errors
# 265 http://www.fastenal.com.websiteoutlook.com: Not Run: Exists
# 266 http://www.pngaming.com.websiteoutlook.com: Not Run: Exists
# 267 http://www.uabiz.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 268 http://www.xyleminc.com.websiteoutlook.com: Not Run: Exists
# 269 http://www.skx.com.websiteoutlook.com: Not Run: Exists
# 270 http://www.ametek.com.websiteoutlook.com: Not Run: Exists
# 271 http://www.iff.com.websiteoutlook.com: Not Run: Exists
# 272 http://www.adt.com.websiteoutlook.com: Not Run: Exists
# 273 www.welltower.com.websiteoutlook.com: Not Run: Port Errors
# 274 http://www.kemper.com.websiteoutlook.com: Not Run: Exists
# 275 http://www.hyatt.com.websiteoutlook.com: Not Run: Port Errors
# 276 http://www.alexion.com.websiteoutlook.com: Not Run: Exists
# 277 http://www.caci.com.websiteoutlook.com: Not Run: Exists
# 278 http://www.ea.com.websiteoutlook.com: Not Run: Exists
# 279 http://www.vulcanmaterials.com.websiteoutlook.com: Not Run: Exists
# 280 http://www.treehousefoods.com.websiteoutlook.com: Not Run: Exists
# 281 http://www.globalpaymentsinc.com.websiteoutlook.com: Not Run: Port Errors
# 282 http://www.cmegroup.com.websiteoutlook.com: Not Run: Exists
# 283 http://www.moodys.com.websiteoutlook.com: Not Run: Port Errors
# 284 http://www.carlisle.com.websiteoutlook.com: Not Run: Port Errors
# 285 http://www.watsco.com.websiteoutlook.com: Not Run: Port Errors
# 286 http://www.taylormorrison.com.websiteoutlook.com: Not Run: Exists
# 287 http://www.iac.com.websiteoutlook.com: Not Run: Exists
# 288 http://www.leggett.com.websiteoutlook.com: Not Run: Exists
# 289 www.archrock.com.websiteoutlook.com: Not Run: Port Errors
# 290 http://www.martinmarietta.com.websiteoutlook.com: Not Run: Exists
# 291 http://www.hasbro.com.websiteoutlook.com: Not Run: Exists
# 292 http://www.fmc.com.websiteoutlook.com: Not Run: Exists
# 293 http://www.bc.com.websiteoutlook.com: Not Run: Port Errors
# 294 http://www.greif.com.websiteoutlook.com: Not Run: Exists
# 295 http://www.concho.com.websiteoutlook.com: Not Run: Exists
# 296 http://www.hubbell.com.websiteoutlook.com: Not Run: Port Errors
# 297 http://www.brunswick.com.websiteoutlook.com: Not Run: Port Errors
# 298 http://www.kbhome.com.websiteoutlook.com: Not Run: Port Errors
# 299 http://www.ryerson.com.websiteoutlook.com: Not Run: Exists
# 300 http://www.silganholdings.com.websiteoutlook.com: Not Run: Exists
# 301 http://www.intuitivesurgical.com.websiteoutlook.com: Not Run: Exists
# 302 http://www.wmg.com.websiteoutlook.com: Not Run: Exists
# 303 http://www.eqt.com.websiteoutlook.com: New Scraping Exception 1st Block
# 304 http://www.ufpi.com.websiteoutlook.com: Not Run: Exists
# 305 http://www.anteroresources.com.websiteoutlook.com: Not Run: Exists
# 306 http://www.meritor.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 307 http://www.broadridge.com.websiteoutlook.com: Not Run: Exists
# 308 http://www.churchdwight.com.websiteoutlook.com: Not Run: Exists
# 309 http://www.edwards.com.websiteoutlook.com: Not Run: Exists
# 310 http://www.insperity.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 311 http://www.ae.com.websiteoutlook.com: Not Run: Exists
# 312 http://www.ironmountain.com.websiteoutlook.com: Not Run: Exists
# 313 http://www.gartner.com.websiteoutlook.com: Not Run: Exists
# 314 http://www.ingles-markets.com.websiteoutlook.com: New Scraping Exception 1st Block
# 315 http://www.monsterbevcorp.com.websiteoutlook.com: Not Run: Exists
# 316 http://www.flowersfoods.com.websiteoutlook.com: Not Run: Exists
# 317 http://www.cunamutual.com.websiteoutlook.com: Not Run: Exists
# 318 http://www.odfl.com.websiteoutlook.com: Not Run: Exists
# 319 http://www.landstar.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 320 http://www.anico.com.websiteoutlook.com: Not Run: Exists
# 321 http://www.brookdale.com.websiteoutlook.com: New Port Exception
# 322 http://www.amkor.com.websiteoutlook.com: Not Run: Exists
# 323 http://www.dentsplysirona.com.websiteoutlook.com: Not Run: Port Errors
# 324 http://www.urbanoutfittersinc.com.websiteoutlook.com: New Scraping Exception 1st Block
# 325 http://www.sabre.com.websiteoutlook.com: Not Run: Exists
# 326 http://www.mercuryinsurance.com.websiteoutlook.com: Not Run: Port Errors
# 327 http://www.aarons.com.websiteoutlook.com: Not Run: Exists
# 328 http://www.scansource.com.websiteoutlook.com: Not Run: Exists
# 329 http://www.ventasreit.com.websiteoutlook.com: Not Run: Exists
# 330 http://www.countryfinancial.com.websiteoutlook.com: Not Run: Exists
# 331 http://www.trinet.com.websiteoutlook.com: Not Run: Exists
# 332 http://www.comerica.com.websiteoutlook.com: Not Run: Port Errors
# 333 http://www.lennoxinternational.com.websiteoutlook.com: Not Run: Exists
# 334 http://www.paychex.com.websiteoutlook.com: Not Run: Exists
# 335 http://www.amerco.com.websiteoutlook.com: Not Run: Exists
# 336 http://www.worthingtonindustries.com.websiteoutlook.com: Not Run: Exists
# 337 http://www.pennmutual.com.websiteoutlook.com: Not Run: Exists
# 338 http://www.sentry.com.websiteoutlook.com: Not Run: Port Errors
# 339 http://www.acuitybrands.com.websiteoutlook.com: Not Run: Exists
# 340 http://www.hubgroup.com.websiteoutlook.com: Not Run: Exists
# 341 http://www.meritagehomes.com.websiteoutlook.com: Not Run: Exists
# 342 http://www.alliantenergy.com.websiteoutlook.com: Not Run: Exists
# 343 http://www.amwater.com.websiteoutlook.com: Not Run: Exists
# 344 http://www.albemarle.com.websiteoutlook.com: Not Run: Exists
# 345 http://www.ciena.com.websiteoutlook.com: Not Run: Exists
# 346 http://www.weismarkets.com.websiteoutlook.com: Not Run: Exists
# 347 http://www.carters.com.websiteoutlook.com: Not Run: Exists
# 348 http://www.stifel.com.websiteoutlook.com: Not Run: Exists
# 349 http://www.mednax.com.websiteoutlook.com: Not Run: Exists
# 350 http://www.equifax.com.websiteoutlook.com: Not Run: Exists
# 351 http://www.karauctionservices.com.websiteoutlook.com: Not Run: Exists
# 352 http://www.medmutual.com.websiteoutlook.com: Not Run: Exists
# 353 http://www.applied.com.websiteoutlook.com: Not Run: Port Errors
# 354 http://www.american-equity.com.websiteoutlook.com: Not Run: Port Errors
# 355 http://www.steelcase.com.websiteoutlook.com: Not Run: Exists
# 356 http://www.sandersonfarms.com.websiteoutlook.com: Not Run: Exists
# 357 http://www.wabco-auto.com.websiteoutlook.com: Not Run: Exists
# 358 http://www.pugetenergy.com.websiteoutlook.com: New Scraping Exception 1st Block
# 359 http://www.graniteconstruction.com.websiteoutlook.com: Not Run: Exists
# 360 http://www.skyworksinc.com.websiteoutlook.com: Not Run: Exists
# 361 http://www.hologic.com.websiteoutlook.com: Not Run: Exists
# 362 http://www.mscdirect.com.websiteoutlook.com: Not Run: Port Errors
# 363 http://www.synopsys.com.websiteoutlook.com: Not Run: Exists
# 364 http://www.boydgaming.com.websiteoutlook.com: Not Run: Exists
# 365 http://www.stericycle.com.websiteoutlook.com: Not Run: Exists
# 366 http://www.craneco.com.websiteoutlook.com: Not Run: Exists
# 367 http://www.cinemark.com.websiteoutlook.com: Not Run: Port Errors
# 368 http://www.autodesk.com.websiteoutlook.com: Not Run: Exists
# 369 http://www.zionsbancorporation.com.websiteoutlook.com: Not Run: Port Errors
# 370 http://www.sci-corp.com.websiteoutlook.com: Not Run: Exists
# 371 http://www.varian.com.websiteoutlook.com: Not Run: Exists
# 372 http://www.pricesmart.com.websiteoutlook.com: Not Run: Exists
# 373 http://www.brinker.com.websiteoutlook.com: Not Run: Exists
# 374 http://www.poolcorp.com.websiteoutlook.com: Not Run: Exists
# 375 http://www.plexus.com.websiteoutlook.com: Not Run: Exists
# 376 http://www.teledyne.com.websiteoutlook.com: Not Run: Exists
# 377 http://www.etrade.com.websiteoutlook.com: Not Run: Exists
# 378 http://www.thetorocompany.com.websiteoutlook.com: New Scraping Exception 1st Block
# 379 http://www.tetratech.com.websiteoutlook.com: Not Run: Exists
# 380 http://www.prim.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 381 http://www.crackerbarrel.com.websiteoutlook.com: Not Run: Exists
# 382 http://www.amcnetworks.com.websiteoutlook.com: Not Run: Exists
# 383 http://www.xilinx.com.websiteoutlook.com: Not Run: Exists
# 384 http://www.columbia.com.websiteoutlook.com: Not Run: Exists
# 385 http://www.mutualofamerica.com.websiteoutlook.com: Not Run: Exists
# 386 http://www.lincolnelectric.com.websiteoutlook.com: Not Run: Exists
# 387 http://www.aosmith.com.websiteoutlook.com: Not Run: Exists
# 388 http://www.arcb.com.websiteoutlook.com: New Scraping Exception 1st Block
# 389 http://www.bostonproperties.com.websiteoutlook.com: Not Run: Exists
# 390 http://www.caleres.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 391 http://www.moog.com.websiteoutlook.com: Not Run: Exists
# 392 http://www.leggmason.com.websiteoutlook.com: Not Run: Port Errors
# 393 http://www.hbfuller.com.websiteoutlook.com: Not Run: Exists
# 394 http://www.perkinelmer.com.websiteoutlook.com: Not Run: Exists
# 395 http://www.kcsouthern.com.websiteoutlook.com: Not Run: Exists
# 396 http://www.aptar.com.websiteoutlook.com: Not Run: Exists
# 397 http://www.publicstorage.com.websiteoutlook.com: Not Run: Exists
# 398 http://www.selective.com.websiteoutlook.com: Not Run: Exists
# 399 http://www.itt.com.websiteoutlook.com: Not Run: Exists
# 400 http://www.donaldson.com.websiteoutlook.com: Not Run: Exists
# 401 http://www.kirbycorp.com.websiteoutlook.com: Not Run: Exists
# 402 http://www.hawaiianairlines.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 403 http://www.popular.com.websiteoutlook.com: Not Run: Exists
# 404 http://www.pcconnection.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 405 http://www.amica.com.websiteoutlook.com: Not Run: Exists
# 406 http://www.enersys.com.websiteoutlook.com: Not Run: Exists
# 407 http://www.magellanlp.com.websiteoutlook.com: Not Run: Exists
# 408 http://www.hain.com.websiteoutlook.com: Not Run: Exists
# 409 http://www.allisontransmission.com.websiteoutlook.com: Not Run: Exists
# 410 http://www.guess.com.websiteoutlook.com: Not Run: Exists
# 411 http://www.vishay.com.websiteoutlook.com: 1...: New Scraping Exception 2nd Block
# 412 http://www.idexcorp.com.websiteoutlook.com: Not Run: Exists
# 413 http://www.belden.com.websiteoutlook.com: Not Run: Port Errors
# 414 http://www.werner.com.websiteoutlook.com: Not Run: Exists
# 415 http://www.muellerindustries.com.websiteoutlook.com: Not Run: Exists
# 416 http://www.kofc.org.websiteoutlook.com: Not Run: Exists
# 417 http://www.cartech.com.websiteoutlook.com: Not Run: Exists
# 418 http://www.trueblue.com.websiteoutlook.com: Not Run: Exists
# 419 http://www.hnicorp.com.websiteoutlook.com: Not Run: Exists
# 420 http://www.rexnord.com.websiteoutlook.com: Not Run: Exists
# 421 http://www.aarcorp.com.websiteoutlook.com: Not Run: Exists
# 422 http://www.khov.com.websiteoutlook.com: Not Run: Exists

# %%
print('Total Websites:' + str(len(fortuneURLs_df['is_run'])))
print('Scraping Completed:' + str(sum(1 for r in fortuneURLs_df['is_run'] if r >= 1)))
print('\tAll 3 Blocks Completed:' + str(sum(1 for r in fortuneURLs_df['is_run'] if r == 3)))
print('\t2 Blocks Completed:' + str(sum(1 for r in fortuneURLs_df['is_run'] if r == 2)))
print('\tOnly 1 Block Completed:' + str(sum(1 for r in fortuneURLs_df['is_run'] if r == 1)))
print('Not Run/Incomplete:'+ str(sum(1 for r in fortuneURLs_df['is_run'] if r == 0)))
print('Port Exceptions:'+ str(sum(1 for r in fortuneURLs_df['is_run'] if r < 0)))
# Out:
# Total Websites:423
# Scraping Completed:348
# 	All 3 Blocks Completed:0
# 	2 Blocks Completed:0
# 	Only 1 Block Completed:348
# Not Run/Incomplete:13
# Port Exceptions:62

# %%
# df specifications

#fortuneURLs_df.shape               # column row count
fortuneURLs_df.head()              # data peak
#fortuneURLs_df.describe()          # statistic details
#fortuneURLs_df.info()              # column list
#fortuneURLs_df.isna().any()        # check NA
# Out:
#    Rank                Name  Revenue($m)  Profits($m)  Assets($m)  \
# 0     1             Walmart     523964.0      14881.0    236495.0
# 1     2          Amazon.com     280522.0      11588.0    225248.0
# 2     4               Apple     260174.0      55256.0    338516.0
# 3     5          CVS Health     256776.0       6634.0    222449.0
# 4     7  UnitedHealth Group     242155.0      13839.0    173889.0
#
#    Market Value($m)  Employees                              URLs  \
# 0          321803.3    2200000            http://www.walmart.com
# 1          970680.1     798000             http://www.amazon.com
# 2         1112640.8     137000              http://www.apple.com
# 3           77375.8     290000          http://www.cvshealth.com
# 4          236555.2     325000  http://www.unitedhealthgroup.com
#
#                                                 wout alexaRank  ... pageSize  \
# 0          http://www.walmart.com.websiteoutlook.com       126  ...     64Kb
# 1           http://www.amazon.com.websiteoutlook.com        14  ...     64Kb
# 2            http://www.apple.com.websiteoutlook.com        51  ...     64Kb
# 3        http://www.cvshealth.com.websiteoutlook.com     31978  ...     64Kb
# 4  http://www.unitedhealthgroup.com.websiteoutloo...     25580  ...     64Kb
#
#   codeToTextRatio semrushRank  keywords organicTraffic        cost  \
# 0           0.68%          15  29145287      190314352  124437628$
# 1           0.27%           3  91384723      950416767  724598977$
# 2          13.71%          20  17897033      159102793  220655359$
# 3          23.26%
# 4          18.54%       10993     15919         133787     459981$
#
#   adwordsKeywords adwordsTraffic adwordsBudget is_run
# 0           37053        3949947      2396610$      1
# 1           79995        2943519      9398034$      1
# 2           15095        3382490      3923068$      1
# 3                                                  -1
# 4             173           2898         1324$      1
#
# [5 rows x 26 columns]

# %% [markdown]
# ### <font style = 'italic'> eof

# %%
# export processed sample set
fortuneURLs_df.to_csv('op_Final.csv')
